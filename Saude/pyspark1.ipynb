# %%
#!apt-get install openjdk-8-jdk-headless -qq > /dev/null
#!apt-get update
#!apt-get upgrade
#!wget https://www-us.apache.org/dist/spark/spark-2.4.4/pyspark-2.4.4.tar.gz
# !tar xf pyspark-2.4.4.tar.gz
# !pip install -q findspark
# !ls -la
# !pwd
# !spark -version
