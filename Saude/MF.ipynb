# %% [markdown]
# ##Engenharia de Dados
#  Jose R F Junior - web2ajax@gmail.com

# %% [markdown]
# #Ministério da Fazenda - MF

# %% [markdown]
# http://www.dados.gov.br/dataset?res_format=CSV

# %%
# %time 
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.0-preview2/spark-3.0.0-preview2-bin-hadoop3.2.tgz
# !tar xf spark-3.0.0-preview2-bin-hadoop3.2.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-preview2-bin-hadoop3.2"

# %%
# %time 
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext, SparkSession
from pyspark.streaming import StreamingContext
from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, StringType
#from pyspark.sql.types import *

# %%
# %time 
ss = SparkSession.builder.master("local[*]").getOrCreate()
sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
sql_sc = SQLContext(sc)
ssc = StreamingContext(sc, 2)

# %%
# %time 
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd
import pyarrow as pa

# %%
import time
# %time 
start = time.time()

! wget -c http://api.pgi.gov.br/api/1/serie/2436.xml

print('seconds: {}'.format(time.time()-start))

# %%
import pandas as pd
import time
# %time 
start = time.time()

#pandas_dfPostos = pd.read_csv('/content/Postos.csv', encoding='utf-8')
pandas_dfPostos = pd.read_csv('/content/PrecoTaxaTesouroDireto.csv', encoding='utf-8',na_values='(missing)', sep=';')

print('seconds: {}'.format(time.time()-start))

# %%
pandas_dfPostos.dtypes

# %%
pandas_dfPostos

# %%
import pandas as pd
import time
# %time 
start = time.time()

VendasTesouroDireto = pd.read_csv('/content/VendasTesouroDireto.csv', encoding='utf-8',na_values='(missing)', sep=';')

print('seconds: {}'.format(time.time()-start))

# %%
VendasTesouroDireto

# %%
import pandas as pd
import time
# %time 
start = time.time()

RecomprasTesouroDireto = pd.read_csv('/content/RecomprasTesouroDireto.csv', encoding='utf-8',na_values='(missing)', sep=';')

print('seconds: {}'.format(time.time()-start))

# %%
RecomprasTesouroDireto
