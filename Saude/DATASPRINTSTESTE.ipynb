# %% [markdown]
# ##SESSION

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.0-preview2/spark-3.0.0-preview2-bin-hadoop3.2.tgz
# !tar xf spark-3.0.0-preview2-bin-hadoop3.2.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-preview2-bin-hadoop3.2"
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext, SparkSession
from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, StringType

# %% [markdown]
# ##SESSION

# %%
#Spark Contexto
ss = SparkSession.builder.master("local[*]").getOrCreate()
sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
sql_sc = SQLContext(sc)

# %%
import pandas as pd

# %%
# %time ! wget -c s3.amazonaws.com/data-sprints-eng-test/data-sample_data-nyctaxi-trips-2009-json_corrigido.json
# %time ! wget -c s3.amazonaws.com/data-sprints-eng-test/data-sample_data-nyctaxi-trips-2010-json_corrigido.json
# %time ! wget -c s3.amazonaws.com/data-sprints-eng-test/data-sample_data-nyctaxi-trips-2011-json_corrigido.json
# %time ! wget -c s3.amazonaws.com/data-sprints-eng-test/data-sample_data-nyctaxi-trips-2012-json_corrigido.json
# %time ! wget -c s3.amazonaws.com/data-sprints-eng-test/data-vendor_lookup-csv.csv
# %time ! wget -c s3.amazonaws.com/data-sprints-eng-test/data-payment_lookup-csv.csv

# %% [markdown]
# ##VENDOR CRIANDO DATAFRAME

# %%
#pandas_dfv = sc.textFile('/content/data-vendor_lookup-csv.csv').collect()
pandas_dfv = pd.read_csv('/content/data-vendor_lookup-csv.csv')
s_dfv = sql_sc.createDataFrame(pandas_dfv)
s_dfv.printSchema()
s_dfv.show()

# %% [markdown]
# #VENDEOR CONSULTADO DATA FRAME

# %%
s_dfv.createOrReplaceTempView("vendor")
sqlDF = sql_sc.sql("SELECT * FROM vendor v")
sqlDF.show()
sqlDF.take(50)

# %% [markdown]
# ## 2009/2010/2011/2012 JSON - Single-line mode

# %%
#import pandas as pd
#df = pd.read_json('/content/teste2.json', orient='columns')
#print(df.head())
import numpy as np
import pandas as pd
import json 
from pandas.io.json import json_normalize
df = pd.read_json('/content/teste2.json')
df.head()

#pandas_teste = pd.read_json('/content/content/teste.json')
#s_dfX = sql_sc.createDataFrame(pandas_teste)
#s_dfX.printSchema()
#s_dfX.show()

#pandas_dfv = pd.read_csv('/content/data-vendor_lookup-csv.csv')
#s_dfv = sql_sc.createDataFrame(pandas_dfv)
#s_dfv.printSchema()
#s_dfv.show()

# %%
#df2009 = ss.read.json('/content/data-sample_data-nyctaxi-trips-2009-json_corrigido.json')
#df2009.printSchema()
pandas_df2009 = pd.read_csv('/content/data-sample_data-nyctaxi-trips-2009-json_corrigido.json')
s_dfv = sql_sc.createDataFrame(pandas_df2009)
s_dfv.printSchema()
s_dfv.show()

# %%
df2010 = ss.read.json('/content/data-sample_data-nyctaxi-trips-2010-json_corrigido.json')
df2010.printSchema()

# %%
df2011 = ss.read.json('/content/data-sample_data-nyctaxi-trips-2011-json_corrigido.json')
df2011.printSchema()

# %%
df2012 = ss.read.json('/content/data-sample_data-nyctaxi-trips-2012-json_corrigido.json')
df2012.printSchema()

# %%
import matplotlib.pyplot as plt
s_dfv.createOrReplaceTempView("VENDOR")
sqlDF = sql_sc.sql("SELECT * FROM VENDOR")
sqlDF.show()
sqlDF.take(50)

# %% [markdown]
# ##PAYMENT

# %%
btp = sc.textFile('/content/data-payment_lookup-csv.csv').collect()
pandas_dfp = pd.read_csv('/content/data-payment_lookup-csv.csv')
s_dfp = sql_sc.createDataFrame(pandas_dfp)
s_dfp.printSchema()
s_dfp.show()

# %%
import matplotlib.pyplot as plt
s_dfv.createOrReplaceTempView("vendor")
s_dfp.createOrReplaceTempView("payment")
#sqlDF = sql_sc.sql("SELECT * FROM payment p, vendor v, sales vp WHERE vp.vendor_id = v.vendor_id AND vp.payment_type = p.a")
sqlDF = sql_sc.sql("SELECT * FROM payment p, vendor v")
sqlDF.show()
sqlDF.take(50)

# %%
bt2009 = df.textFile('/content/data-sample_data-nyctaxi-trips-2009-json_corrigido.json').collect()
pandas_df2009 = pd.read_csv('/content/data-sample_data-nyctaxi-trips-2009-json_corrigido.json')
s_df2009 = sql_sc.createDataFrame(pandas_df2009)
s_df2009.printSchema()
#s_df2009.show()
#s_df2009.take(50)

# %%
s_df1 = sql_sc.createDataFrame(pandas_df1)
s_df1.printSchema()
s_df1.show()
s_df1.select("deathsMS").show()
s_df1.groupBy("deathsMS").count().show()
s_df1.select(s_df1['state'], s_df1['totalCases'], s_df1['deathsMS']).show()
s_df1.filter(s_df1['deathsMS'] > 100).show()
s_df1.groupBy("deathsMS").count().show()

# %% [markdown]
# #Cria um DataFrame e consulta

# %%
import matplotlib.pyplot as plt
s_df1.createOrReplaceTempView("COVID19")
sqlDF = sql_sc.sql("SELECT state, totalCases, deathsMS  FROM COVID19 WHERE deathsMS > 1 ")
sqlDF.show()
sqlDF.take(50)

# %%
import matplotlib.pyplot as plt
s_df1.createOrReplaceTempView("COVID19")
sqlDF = sql_sc.sql("SELECT state, totalCases, deathsMS  FROM COVID19 WHERE deathsMS > 1 ")
sqlDF.show()
sqlDF.take(50)

# %%
x1 =  [1,2,3]
y1 =  [1,2,3]
plt.bar(x1,y1)

# %%
s_df2.createOrReplaceTempView("COVID19s_df2")
sqlDF = sql_sc.sql("SELECT state, date, totalCases FROM COVID19s_df2")
#sqlDF.show()
#sqlDF.take(30)
s_df2.groupBy("date").sum("totalCases").show(300)
s_df2.write.format('com.databricks.spark.csv').save('/content/covid19br/tota3.csv')
sqlDF.take(30)

# %%
s_df3 = sql_sc.createDataFrame(pandas_df3)
s_df3.show()

# %%
s_df3 = sql_sc.createDataFrame(pandas_df3)
s_df3.show()

# %%
s_df4 = sql_sc.createDataFrame(pandas_df4)
s_df4.show()

# %%
s_df5 = sql_sc.createDataFrame(pandas_df5)
s_df5.show()

# %%
s_df6 = sql_sc.createDataFrame(pandas_df6)
s_df6.show()

# %%
s_df6 = sql_sc.createDataFrame(pandas_df6)
s_df6.show()

# %%
s_df7 = sql_sc.createDataFrame(pandas_df7)
s_df7.show()

# %% [markdown]
# O próximo bloco de código configurará a série temporal com sazonalidade, tendência e um pouco de ruído.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Tempo")
    plt.ylabel("Valor")
    plt.grid(True)

# %%
def trend(time, slope=0):
    return slope * time

# %%
def seasonal_pattern(season_time):
    return np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

# %%
def seasonality(time, period, amplitude=1, phase=0):
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

# %%
def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

# %%
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
series = trend(time, 0.1)  
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# %%
# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += noise(time, noise_level, seed=42)

# %%
plt.figure(figsize=(10, 6))
plot_series(time, series)
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# Dados
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.xlabel('TEMPO')
plt.ylabel('PROBABILIDADE')
plt.title('PICO DE MORTES')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import numpy as np
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
np.random.seed(19680801)

# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure()

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()
