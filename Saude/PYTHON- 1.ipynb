# %% [markdown]
# ##IMPORTAR PANDAS

# %%
import pandas as pd
pandas.__version__

# %% [markdown]
# ##DUVIDAS ?

# %% [markdown]
# https://entrenamiento-python-basico.readthedocs.io/es/latest/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #?

# %%
a = 1
b = 2
c = a + b

# %%
print(c)

# %%
a = 1
b = 2
c = a - b

# %%
print(c)

# %% [markdown]
# #?

# %%
a = 1
b = 2

# %%
b == 1

# %%
a == 2

# %%
a == 1

# %%
b == 2

# %%
a = 2 
b = 2

# %%
c = a * b
print(c)

# %%
c = a / b
print(c)

# %%
c = "pip"
print(c)

# %% [markdown]
# #Pandas
#
# ![image.png](data:image/png;base64,...)
#
# https://pandas.pydata.org/docs/development/index.html#development

# %% [markdown]
# #?

# %%
df = pd.DataFrame({
                   'nome':['MARIA','MARIA','JUNIOR','LUPE'],
                   'idade':[20,50,30,60],
                   'salario':[5.000,6.099,3.880,20.000],
                   'animal':['GATO','GATO', 'CACHORRO', 'GATO'
                   ]})

# %% [markdown]
# #?

# %%
df

# %% [markdown]
# #?

# %%
df.head()

# %%
df.tail(1)

# %%
df.tail(2)

# %%
df.tail(3)

# %% [markdown]
# #?

# %%
df.info()

# %%
df.describe().T

# %% [markdown]
# #?

# %%
df[df.animal=='GATO']

# %%
df[df.animal=='gato']

# %%
df[df.nome=='MARIA']

# %%
df[df.nome=='maria']

# %% [markdown]
# #?

# %%
print(df['nome'])
print(df.nome)

# %% [markdown]
# #?

# %%
df.nome[df.nome=='MARIA'].count()

# %%
df.nome[df.nome=='maria'].count()

# %%
df.nome[df.nome=='JUNIOR'].count()

# %% [markdown]
# #?

# %%
df[(df.nome=='MARIA')&(df.idade>=21)]

# %%
df[(df.nome=='MARIA')&(df.idade>=20)]

# %%
df[(df.nome=='MARIA')&(df.idade>=18)].mean()

# %% [markdown]
# #?

# %%
df.describe

# %% [markdown]
# #?

# %%
df.describe()

# %%
df.describe().salario

# %% [markdown]
# #?

# %%
df.head()

# %% [markdown]
# #?

# %%
df.head

# %% [markdown]
# #?

# %%
df[['nome','animal']]

# %% [markdown]
# #?

# %%
df.iloc[0]

# %% [markdown]
# #?

# %%
df.iloc[1]

# %% [markdown]
# #?

# %%
df.iloc[2]

# %% [markdown]
# #?

# %%
df.sort_values('animal',inplace=True, ascending=True)
df

# %% [markdown]
# #?

# %%
df.sort_values('animal',inplace=True, ascending=False)
df

# %% [markdown]
# #?

# %%
df.loc[0] #index based

# %%
df.loc[1] #index based

# %%
df.loc[2] #index based

# %% [markdown]
# #?

# %%
df.iloc[:,2]

# %%
df.iloc[-1,:]

# %% [markdown]
# #?

# %%
df.sort_values('animal',inplace=True, ascending=True)
df

# %%
df.sort_values('animal',inplace=True, ascending=False)
df

# %% [markdown]
# ##Basic Pandas Concept Exercises

# %%
sales = [100,130,119,92,35]
customer_account = ['B100','J101','X102','P103','R104']
city = ['BOS','LA','NYC','SF','CHI']

# %% [markdown]
# #Create a DataFrame with the data above

# %% [markdown]
# #What is the name of the first column?

# %% [markdown]
# #Sort the DataFrame by city in descending order (check the documentation for sort)

# %% [markdown]
# #Which customer is in the last row of the DataFrame?

# %% [markdown]
# #Reorder the columns with customer in the first column
