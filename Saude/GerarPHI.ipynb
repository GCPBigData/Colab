# %% [markdown]
# Jose R F Junior
#
# web2ajax@gmail.com
#
# Gerador de PHI φ

# %%
φ

# %%
x = n
while x >= n:
    with open('phi.txt', 'a') as f:
        print(phi(n), file=f)
    f.close()

# %%
print(phi(n))
